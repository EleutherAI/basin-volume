# %%
from jacobian import *

cfg = TrainConfig(num_epochs=25, optimizer="adam", lr=0.1)

key = jax.random.key(seed)
ref_key, key = jax.random.split(key)

ref_params = model.init(ref_key, X)
raveled_ref_params, unravel = ravel_pytree(ref_params)

@partial(jax.pmap, in_axes=(0))
def train_pmap(raveled_params):
    J, (metrics, state) = jac_fn(raveled_params, X, Y, model.apply, cfg, unravel)
    final_params, (metrics, state) = train(raveled_params, X, Y, model.apply, cfg, unravel)
    return final_params, J, metrics, state


def expt(iters=1,
         save_dir=".",
         symmetric=False,
         canonicalize=False,
         aligned=False,
         return_J=False):
    keys = jax.random.split(key, 8 * iters)

    delta_bulks = []
    deltas = []
    Js = []

    for i in trange(iters):
        init_params = []
        for j in range(8):
            init_param = model.init(keys[i * 8 + j], X)
            if aligned:
                init_param, _, _ = alignment.align_networks(
                    init_param, 
                    ref_params, 
                    symmetric=symmetric,
                    canonicalize=canonicalize,
                )
            init_param = ravel_pytree(init_param)[0]
            init_params.append(init_param)

        init_params = jnp.stack(init_params)

        final_params, J, metrics, state = train_pmap(init_params)

        loss, accuracy = metrics
        print(loss, accuracy)

        u8, s8, vt8 = jax.pmap(jnp.linalg.svd)(J)

        for i in range(8):
            u, s, vt = u8[i], s8[i], vt8[i]
            final_params_i = final_params[i]
            init_params_i = init_params[i]
            delta = final_params_i - init_params_i
            deltas.append(delta)
            
            dists = jnp.abs(s - 1)
            bulk = jnp.argsort(dists)[:2000]
            proj = vt[bulk, :]
            delta_bulk = proj.T @ (proj @ delta)
            delta_bulks.append(delta_bulk)
            if return_J:
                Js.append(J[i])

    deltas = jnp.stack(deltas)

    delta_bulks = jnp.stack(delta_bulks)
    delta_bulks_mean = jnp.mean(delta_bulks, axis=0)
    delta_bulks_cov = jnp.cov(delta_bulks, rowvar=False)
    print(delta_bulks_mean.shape, delta_bulks_cov.shape)
    print(jnp.linalg.norm(delta_bulks_mean))
    print((jnp.linalg.norm(delta_bulks, axis=1)))
    print("ratio:", jnp.mean(jnp.linalg.norm(delta_bulks, axis=1)**2) / jnp.linalg.norm(delta_bulks_mean)**2)

    # u, s, vt = jnp.linalg.svd(delta_bulks_cov)
    # print(s[:20])

    if return_J:
        Js = jnp.stack(Js)

    # write to file with timestamp
    data = {
        "symmetric": symmetric,
        "canonicalize": canonicalize,
        "aligned": aligned,
        "delta_bulks": delta_bulks,
        "Js": Js,
    }
    if save_dir is not None:
        with open(f"{save_dir}/delta_bulk_{time.time()}.pkl", "wb") as f:
            pickle.dump(data, f)

    return deltas, delta_bulks, Js

# %%
expt()
# Out:
#   0%|          | 0/1 [00:18<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 expt()
#
# Cell In[3], line 46, in expt(iters, save_dir, symmetric, canonicalize, aligned, return_J)
#      42     init_params.append(init_param)
#      44 init_params = jnp.stack(init_params)
# ---> 46 final_params, J, metrics, state = train_pmap(init_params)
#      48 loss, accuracy = metrics
#      49 print(loss, accuracy)
#
#     [... skipping hidden 1 frame]
#
# File ~/.conda/envs/jax_py311/lib/python3.11/site-packages/jax/_src/api.py:1780, in _cpp_pmap.<locals>.cache_miss(*args, **kwargs)
#    1778 if isinstance(top_trace, core.EvalTrace):
#    1779   execute = pxla.xla_pmap_impl_lazy(fun_, *tracers, **params)
# -> 1780   out = map_bind_continuation(execute(*tracers))
#    1781 else:
#    1782   out = map_bind_continuation(
#    1783       pxla.xla_pmap_p.process(top_trace, fun_, tracers, params))
#
# File ~/.conda/envs/jax_py311/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.conda/envs/jax_py311/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1248, in ExecuteReplicated.__call__(self, *args)
#    1246   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1247 else:
# -> 1248   results = self.xla_executable.execute_sharded(input_bufs)
#    1250 if dispatch.needs_check_special():
#    1251   out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:
